# %% [markdown]
# Image Preprocessing Data

# %%
# !wget 'https://tractive.com/blog/wp-content/uploads/2016/04/puppy-care-guide-for-new-parents.jpg'
# Out:
# --2023-10-12 12:22:26--  https://tractive.com/blog/wp-content/uploads/2016/04/puppy-care-guide-for-new-parents.jpg
# Resolving tractive.com (tractive.com)... 65.8.248.23, 65.8.248.7, 65.8.248.99, ...
# Connecting to tractive.com (tractive.com)|65.8.248.23|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 113570 (111K) [image/jpeg]
# Saving to: ‘puppy-care-guide-for-new-parents.jpg’
#
# puppy-care-guide-fo 100%[===================>] 110.91K   608KB/s    in 0.2s
#
# 2023-10-12 12:22:26 (608 KB/s) - ‘puppy-care-guide-for-new-parents.jpg’ saved [113570/113570]

# %%
import cv2
import matplotlib.pyplot as plt
img = cv2.imread('/content/dog.jpg')

# %%
print(img.shape)
# Out:
# (1365, 2048, 3)

# %%
type(img)
# Out:
# numpy.ndarray

# %%
cv2_imshow(img)

# %%
print(img)
# Out:
# [[[  0 182 147]
#   [  0 182 147]
#   [  0 182 147]
#   ...
#   [  0 148 128]
#   [  0 148 128]
#   [  0 148 128]]
#
#  [[  0 181 146]
#   [  0 181 146]
#   [  0 182 147]
#   ...
#   [  0 148 128]
#   [  0 148 128]
#   [  0 148 128]]
#
#  [[  0 180 145]
#   [  0 180 145]
#   [  0 180 145]
#   ...
#   [  0 148 128]
#   [  0 148 128]
#   [  0 148 128]]
#
#  ...
#
#  [[ 25  69  76]
#   [ 25  69  76]
#   [ 24  68  75]
#   ...
#   [ 38 106 135]
#   [ 38 106 135]
#   [ 38 106 135]]
#
#  [[ 25  69  76]
#   [ 25  69  76]
#   [ 24  68  75]
#   ...
#   [ 38 106 135]
#   [ 38 106 135]
#   [ 38 106 135]]
#
#  [[ 25  69  76]
#   [ 25  69  76]
#   [ 24  68  75]
#   ...
#   [ 38 106 135]
#   [ 38 106 135]
#   [ 38 106 135]]]

# %%
import cv2

# %%
gray_image = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)

# %%
type(gray_image)
# Out:
# numpy.ndarray

# %%
from google.colab.patches import cv2_imshow

# %%
cv2_imshow(gray_image)
# Out:
# <PIL.Image.Image image mode=L size=2048x1365>

# %%
cv2.imwrite('grayScale_image.jpg',gray_image)
# Out:
# True
